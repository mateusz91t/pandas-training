# %% [markdown]
# # Labs 08 (Section 10 - Plots)

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import math
from datetime import datetime, timedelta, time
import seaborn

# %matplotlib inline
plt.style.use('dark_background')

# %% [markdown]
# ## L001

# %%
# Import data
nasa = pd.read_csv(
    './course-files/course-sources/nasa_facebook_statuses.csv',
    usecols=['status_published', 'num_reactions', 'num_comments', 'num_shares', 'num_likes']
)

# Convert column type to date time
nasa['status_published'] = pd.to_datetime(nasa['status_published'])

# Select observations between two datetimes - May 2015
filtered_time = (nasa['status_published'] >= '2016-5-1') & (nasa['status_published'] < '2016-6-1')
nasa = nasa[filtered_time]

# Add column with day only
nasa['day'] = nasa.apply(lambda row: row['status_published'].day, axis=1)

# Group all columns by sum

nasa_by_day = nasa.groupby(by='day').sum()

nasa.head()
# Out:
#        status_published  num_reactions  num_comments  num_shares  num_likes  \
# 137 2016-05-31 20:37:02           3003           339         412       2840
# 138 2016-05-31 19:43:18          29975           259        2620      28646
# 139 2016-05-31 18:04:59          10998           158        1379      10221
# 140 2016-05-31 16:31:30          21482           142        1088      20555
# 141 2016-05-31 15:11:02            958            26          94        914
#
#      day
# 137   31
# 138   31
# 139   31
# 140   31
# 141   31

# %%
nasa_by_day.head()
# Out:
#      num_reactions  num_comments  num_shares  num_likes
# day
# 1            62629           727        4403      60243
# 2           188255          2328       23897     177989
# 3            53700           770       10858      50264
# 4           140098          1776       23360     133302
# 5            93146          1070        7627      89657

# %%
# 3, 5
nasa_by_day.plot()
# Out:
# <AxesSubplot:xlabel='day'>

# %%
# 6
nasa_by_day.num_shares.plot()
# Out:
# <AxesSubplot:xlabel='day'>

# %%
# 7
nasa_by_day.plot(y=['num_shares', 'num_comments'])
# Out:
# <AxesSubplot:xlabel='day'>

# %%
# 8
nasa_by_day.plot(y='num_shares')
# Out:
# <AxesSubplot:xlabel='day'>

# %%
# 9
nasa_by_day[['num_shares', 'num_comments']].plot()
# Out:
# <AxesSubplot:xlabel='day'>

# %% [markdown]
# ## L002

# %%
# 3
nasa_by_day.plot()
# Out:
# <AxesSubplot:xlabel='day'>

# %%
# 4
nasa_by_day.plot(figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='day'>

# %%
# 5
nasa_by_day.plot(figsize=(15, 5), title='NASA Facebook activity')
# Out:
# <AxesSubplot:title={'center':'NASA Facebook activity'}, xlabel='day'>

# %%
# 6
nasa_by_day.plot(figsize=(15, 5), subplots=True)
# Out:
# array([<AxesSubplot:xlabel='day'>, <AxesSubplot:xlabel='day'>,
#        <AxesSubplot:xlabel='day'>, <AxesSubplot:xlabel='day'>],
#       dtype=object)

# %%
# 7
nasa_by_day.plot(figsize=(15, 5), logy=True)
# Out:
# <AxesSubplot:xlabel='day'>

# %%
# 8
nasa_by_day.plot(figsize=(15, 5), xticks=(range(1,32)))
# Out:
# <AxesSubplot:xlabel='day'>

# %%
# 9
nasa_by_day.plot(figsize=(15, 5), xticks=(range(1,32)), rot=45)
# Out:
# <AxesSubplot:xlabel='day'>

# %%
# 10
nasa_by_day.iloc[:10].plot(figsize=(15, 5), table=True)
# Out:
# <AxesSubplot:xlabel='day'>

# %% [markdown]
# ## L003

# %%
# 3
nasa_by_day.plot(figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='day'>

# %%
# 4
nasa_by_day.plot(figsize=(15, 5), color=['r', 'g', 'b', 'w'])
# Out:
# <AxesSubplot:xlabel='day'>

# %%
# 5
nasa_by_day.plot(figsize=(15, 5), colormap='spring')
# Out:
# <AxesSubplot:xlabel='day'>

# %%
# 6
nasa_by_day.plot(figsize=(15, 5), colormap='autumn')
# Out:
# <AxesSubplot:xlabel='day'>

# %%
# 7
plt.style.use('fivethirtyeight')
nasa_by_day.plot(figsize=(15, 5), colormap='autumn')
# Out:
# <AxesSubplot:xlabel='day'>

# %%
# 8
plt.style.use('dark_background')
nasa_by_day.plot(figsize=(15, 5), colormap='autumn')
# Out:
# <AxesSubplot:xlabel='day'>

# %% [markdown]
# ## L004

# %%
#Add column with day only
nasa['month'] = nasa.apply(lambda row: row["status_published"].month,axis=1)

#Group all columns by sum
nasa_by_month = nasa.groupby(by='month').sum()
nasa_by_month.head()

# Import data
nasa = pd.read_csv(
    './course-files/course-sources/nasa_facebook_statuses.csv',
    usecols=['status_published', 'num_reactions', 'num_comments', 'num_shares', 'num_likes']
)

# Convert column type to date time
nasa['status_published'] = pd.to_datetime(nasa['status_published'])

# Select observations between two datetimes - March - May 2016
filtered_time = (nasa['status_published'] >= '2016-3-1') & (nasa['status_published'] < '2016-6-1')
nasa = nasa[filtered_time]

# Add column with day only
nasa['day'] = nasa.apply(lambda row: row['status_published'].day, axis=1)
nasa['month'] = nasa.apply(lambda row: row['status_published'].month, axis=1)

# Group all columns by sum
nasa_by_day = nasa.groupby(by='day').sum()
nasa_by_month = nasa.groupby(by='month').sum()

plt.style.use('seaborn')

nasa.head(2)
# Out:
#        status_published  num_reactions  num_comments  num_shares  num_likes  \
# 137 2016-05-31 20:37:02           3003           339         412       2840
# 138 2016-05-31 19:43:18          29975           259        2620      28646
#
#      day  month
# 137   31      5
# 138   31      5

# %%
nasa_by_day.head(2)
# Out:
#      num_reactions  num_comments  num_shares  num_likes  month
# day
# 1           288880          4727       31688     273613     66
# 2           740863         11284       86792     704247     90

# %%
nasa_by_month
# Out:
#        num_reactions  num_comments  num_shares  num_likes   day
# month
# 3            3003815         49108      392585    2846361  2871
# 4            2927616        120118      370803    2760385  2968
# 5            2708977         46122      393576    2548960  3252

# %%
# 3
nasa_by_month.num_likes.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='num_likes'>

# %%
# 4
nasa_by_month.num_likes.plot(
    kind='pie',
    figsize=(5, 5)
)
# Out:
# <AxesSubplot:ylabel='num_likes'>

# %%
# 5
nasa_by_month.num_likes.plot(
    kind='pie',
    figsize=(5, 5),
    title='NASA Facebook activity'
)
# Out:
# <AxesSubplot:title={'center':'NASA Facebook activity'}, ylabel='num_likes'>

# %%
# 6
cols = list(nasa_by_month.columns)
del cols[-1]
nasa_by_month[cols].plot(
    kind='pie',
    figsize=(10, 10),
    title='NASA Facebook activity',
    subplots=True
)
# Out:
# array([<AxesSubplot:ylabel='num_reactions'>,
#        <AxesSubplot:ylabel='num_comments'>,
#        <AxesSubplot:ylabel='num_shares'>,
#        <AxesSubplot:ylabel='num_likes'>], dtype=object)

# %%
# 7
nasa_by_month[cols].plot(
    kind='pie',
    figsize=(10, 10),
    title='NASA Facebook activity',
    subplots=True,
    layout=(2, 2),
    legend=False
)
# Out:
# array([[<AxesSubplot:ylabel='num_reactions'>,
#         <AxesSubplot:ylabel='num_comments'>],
#        [<AxesSubplot:ylabel='num_shares'>,
#         <AxesSubplot:ylabel='num_likes'>]], dtype=object)

# %%
# 8
nasa_by_month[cols].plot(
    kind='pie',
    figsize=(10, 10),
    title='NASA Facebook activity',
    subplots=True,
    layout=(2, 2),
    legend=True,
    autopct='%.f%%',
    textprops=dict(color='yellow')
)
# Out:
# array([[<AxesSubplot:ylabel='num_reactions'>,
#         <AxesSubplot:ylabel='num_comments'>],
#        [<AxesSubplot:ylabel='num_shares'>,
#         <AxesSubplot:ylabel='num_likes'>]], dtype=object)

# %% [markdown]
# ## L005

# %%
plt.style.use('seaborn')
marathon = pd.read_csv(
    './course-files/course-sources/marathon_results_2017.csv',
    usecols=['Age', 'M/F', 'Country', '40K']
)
marathon
# Out:
#        Age M/F Country      40K
# 0       24   M     KEN  2:02:53
# 1       30   M     USA  2:03:14
# 2       25   M     JPN  2:03:38
# 3       32   M     USA  2:04:35
# 4       31   M     KEN  2:05:00
# ...    ...  ..     ...      ...
# 26405   61   F     USA  6:46:57
# 26406   25   M     USA  6:54:21
# 26407   57   F     USA  6:54:38
# 26408   64   M     USA  6:56:08
# 26409   48   M     USA  7:41:23
#
# [26410 rows x 4 columns]

# %%
marathon['TimeSeconds'] = marathon['40K'].apply(lambda x: pd.Timedelta(x).total_seconds())
marathon
# Out:
#        Age M/F Country      40K  TimeSeconds
# 0       24   M     KEN  2:02:53       7373.0
# 1       30   M     USA  2:03:14       7394.0
# 2       25   M     JPN  2:03:38       7418.0
# 3       32   M     USA  2:04:35       7475.0
# 4       31   M     KEN  2:05:00       7500.0
# ...    ...  ..     ...      ...          ...
# 26405   61   F     USA  6:46:57      24417.0
# 26406   25   M     USA  6:54:21      24861.0
# 26407   57   F     USA  6:54:38      24878.0
# 26408   64   M     USA  6:56:08      24968.0
# 26409   48   M     USA  7:41:23      27683.0
#
# [26410 rows x 5 columns]

# %%
groupMF = marathon[marathon['Country'].isin(['USA','CAN'])].groupby(by=['Country', 'M/F'])
groupMF.first()
# Out:
#              Age      40K  TimeSeconds
# Country M/F
# CAN     F     30  2:32:19       9139.0
#         M     34  2:18:57       8337.0
# USA     F     25  2:15:54       8154.0
#         M     30  2:03:14       7394.0

# %%
groupMF = groupMF.agg({'TimeSeconds': ['mean']})
groupMF
# Out:
#               TimeSeconds
#                      mean
# Country M/F
# CAN     F    13618.346012
#         M    12527.160190
# USA     F    14187.362706
#         M    12998.130515

# %%
groupMF = groupMF.unstack()
groupMF
# Out:
#           TimeSeconds
#                  mean
# M/F                 F             M
# Country
# CAN      13618.346012  12527.160190
# USA      14187.362706  12998.130515

# %%
groupMF.columns = groupMF.columns.droplevel().droplevel()
groupMF
# Out:
# M/F                 F             M
# Country
# CAN      13618.346012  12527.160190
# USA      14187.362706  12998.130515

# %%
# 3
groupMF.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
# 4
groupMF.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
# 5
groupMF.plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
# 6
age_data = marathon[marathon['Country'].isin(['USA'])]
age_data.head()
# Out:
#    Age M/F Country      40K  TimeSeconds
# 1   30   M     USA  2:03:14       7394.0
# 3   32   M     USA  2:04:35       7475.0
# 5   40   M     USA  2:05:21       7521.0
# 6   33   M     USA  2:05:41       7541.0
# 8   27   M     USA  2:07:17       7637.0

# %%
# 7
age_data['Age'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# 8.1
age_data.Age.nunique()
# Out:
# 66

# %%
# 8.2
age_data.Age.plot(kind='hist', bins=66)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# 9
data_USA = marathon[ marathon.Country.isin(['USA']) ]
data_USA.head()
# Out:
#    Age M/F Country      40K  TimeSeconds
# 1   30   M     USA  2:03:14       7394.0
# 3   32   M     USA  2:04:35       7475.0
# 5   40   M     USA  2:05:21       7521.0
# 6   33   M     USA  2:05:41       7541.0
# 8   27   M     USA  2:07:17       7637.0

# %%
# 10
data_USA.Age.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# 11
USA = marathon[ marathon.Country.isin(['USA']) ]['Age']
CAN = marathon[ marathon.Country.isin(['CAN']) ]['Age']
df = pd.DataFrame({'USA': USA, 'CAN': CAN})
df.head()
# Out:
#     USA  CAN
# 1  30.0  NaN
# 3  32.0  NaN
# 5  40.0  NaN
# 6  33.0  NaN
# 8  27.0  NaN

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## L006

# %%
marathon
# Out:
#        Age M/F Country      40K  TimeSeconds
# 0       24   M     KEN  2:02:53       7373.0
# 1       30   M     USA  2:03:14       7394.0
# 2       25   M     JPN  2:03:38       7418.0
# 3       32   M     USA  2:04:35       7475.0
# 4       31   M     KEN  2:05:00       7500.0
# ...    ...  ..     ...      ...          ...
# 26405   61   F     USA  6:46:57      24417.0
# 26406   25   M     USA  6:54:21      24861.0
# 26407   57   F     USA  6:54:38      24878.0
# 26408   64   M     USA  6:56:08      24968.0
# 26409   48   M     USA  7:41:23      27683.0
#
# [26410 rows x 5 columns]

# %%
# 2
marathon.plot(kind='scatter', x='Age', y='TimeSeconds')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='TimeSeconds'>

# %%
# 3
marathon_m = marathon[
    marathon['M/F'] == 'M'
]
marathon_m
# Out:
#        Age M/F Country      40K  TimeSeconds
# 0       24   M     KEN  2:02:53       7373.0
# 1       30   M     USA  2:03:14       7394.0
# 2       25   M     JPN  2:03:38       7418.0
# 3       32   M     USA  2:04:35       7475.0
# 4       31   M     KEN  2:05:00       7500.0
# ...    ...  ..     ...      ...          ...
# 26403   25   M     USA  6:34:28      23668.0
# 26404   19   M     USA  6:42:51      24171.0
# 26406   25   M     USA  6:54:21      24861.0
# 26408   64   M     USA  6:56:08      24968.0
# 26409   48   M     USA  7:41:23      27683.0
#
# [14438 rows x 5 columns]

# %%
marathon_f = marathon[
    marathon['M/F'] == 'F'
]
marathon_f
# Out:
#        Age M/F Country      40K  TimeSeconds
# 20      37   F     KEN  2:14:43       8083.0
# 23      27   F     BRN  2:15:42       8142.0
# 24      25   F     USA  2:15:54       8154.0
# 33      33   F     USA  2:17:25       8245.0
# 43      33   F     KEN  2:19:07       8347.0
# ...    ...  ..     ...      ...          ...
# 26385   37   F     USA  5:55:05      21305.0
# 26396   44   F     USA  6:18:21      22701.0
# 26399   49   F     USA  6:25:56      23156.0
# 26405   61   F     USA  6:46:57      24417.0
# 26407   57   F     USA  6:54:38      24878.0
#
# [11972 rows x 5 columns]

# %%
mx = marathon_m.plot.scatter(x='Age', y='TimeSeconds', color='Blue', label='M')  # Male [męski]
mx
# Out:
# <AxesSubplot:xlabel='Age', ylabel='TimeSeconds'>

# %%
marathon_f.plot.scatter(x='Age', y='TimeSeconds', color='Orange', label='F')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='TimeSeconds'>

# %%
mx = marathon_m.plot.scatter(x='Age', y='TimeSeconds', color='Blue', label='M')  # Male [męski]
mx
# why it doesn't work? :(
marathon_f.plot.scatter(x='Age', y='TimeSeconds', color='Orange', label='Female', ax=mx)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='TimeSeconds'>

# %%
# 5
marathon_m.plot.hexbin(x='Age', y='TimeSeconds', gridsize=30,title='M')
# Out:
# <AxesSubplot:title={'center':'M'}, xlabel='Age', ylabel='TimeSeconds'>

# %%
marathon_f.plot.hexbin(x='Age', y='TimeSeconds', gridsize=30, title='M', sharex=False)
# Out:
# <AxesSubplot:title={'center':'M'}, xlabel='Age', ylabel='TimeSeconds'>

# %%
# 6
#Import data
nasa = pd.read_csv('./course-files/course-sources/nasa_facebook_statuses.csv',
usecols=["status_published","num_likes"])
#Convert column type to date time
nasa["status_published"] = pd.to_datetime(nasa["status_published"])
#Select observations between two datetimes - May 2015
ft =(nasa['status_published'] >= '2016-5-1') & (nasa['status_published'] < '2016-6-1')
nasa = nasa[ft]
#Add column with day only
nasa['day'] = nasa.apply(lambda row: row["status_published"].day,axis=1)
#Group all columns by sum
nasa_by_day = nasa.groupby(by='day').sum()
#Import data
bean = pd.read_csv("./course-files/course-sources/mrbean_facebook_statuses.csv",
usecols=["status_published","num_likes"])
#Convert column type to date time
bean["status_published"] = pd.to_datetime(bean["status_published"])
#Select observations between two datetimes - May 2015
ft =(bean['status_published'] >= '2016-5-1') & (bean['status_published'] < '2016-6-1')
bean = bean[ft]
#Add column with day only
bean['day'] = bean.apply(lambda row: row["status_published"].day,axis=1)
#Group all columns by sum
bean_by_day = bean.groupby(by='day').sum()
days = nasa["day"].append(bean["day"])
days = days.unique()
fb = pd.DataFrame(index=days).sort_index()
fb['nasa'] = nasa_by_day["num_likes"]
fb['bean'] = bean_by_day["num_likes"]
fb.fillna(value=0, inplace=True)
fb.head()
# Out:
#      nasa     bean
# 1   60243      0.0
# 2  177989      0.0
# 3   50264      0.0
# 4  133302  26821.0
# 5   89657      0.0

# %%
fb.plot(kind='area')
# Out:
# <AxesSubplot:>
