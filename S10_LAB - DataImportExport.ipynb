# %% [markdown]
# # Labs 09 (Section 11 - Data import and export)

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import math
import re
import csv

# magic f: %matplotlib inline` seems it is not important now, beacause automatically it works
# %matplotlib inline
plt.style.use('dark_background')  # dark theme

# %% [markdown]
# ## L001

# %%
# 4
df = pd.read_csv(
    './course-files/course-sources/mobile_internet_use_isoc_cimobi_frq.tsv',
    sep='\t'
)
df
# Out:
#          indic_is,ind_type,unit,time\geo EU28  EU27  EU15   EA   BE    BG   \
# 0         I_IHDDAY,CB_EU_FOR,PC_IND,2012   15    15    16   12   15    : u
# 1     I_IHDDAY,CB_EU_FOR,PC_IND_IU3,2012   21    21    21   17   19    : u
# 2    I_IHDDAY,CB_EU_FOR,PC_IND_IUHD,2012   57    57    57   55   48    : u
# 3         I_IHDDAY,CB_EXT_EU,PC_IND,2012   21    21    22   13   11   25 u
# 4     I_IHDDAY,CB_EXT_EU,PC_IND_IU3,2012   28    28    29   19   15   28 u
# ..                                   ...   ...   ...   ...  ...  ...   ...
# 442    I_IHDLTWK,Y75_MAX,PC_IND_IU3,2012    :     :     :    :    :     :
# 443   I_IHDLTWK,Y75_MAX,PC_IND_IUHD,2012    :     :     :    :    :     :
# 444       I_IHDUSE,CB_EU_FOR,PC_IND,2012   22    22    22   18   26    : u
# 445   I_IHDUSE,CB_EU_FOR,PC_IND_IU3,2012   30    30    30   25   33    : u
# 446  I_IHDUSE,CB_EU_FOR,PC_IND_IUHD,2012   82    82    82   81   82    : u
#
# ...

# %%
df_desc = df['indic_is,ind_type,unit,time\\geo']
df_desc
# Out:
# 0           I_IHDDAY,CB_EU_FOR,PC_IND,2012
# 1       I_IHDDAY,CB_EU_FOR,PC_IND_IU3,2012
# 2      I_IHDDAY,CB_EU_FOR,PC_IND_IUHD,2012
# 3           I_IHDDAY,CB_EXT_EU,PC_IND,2012
# 4       I_IHDDAY,CB_EXT_EU,PC_IND_IU3,2012
#                       ...
# 442      I_IHDLTWK,Y75_MAX,PC_IND_IU3,2012
# 443     I_IHDLTWK,Y75_MAX,PC_IND_IUHD,2012
# 444         I_IHDUSE,CB_EU_FOR,PC_IND,2012
# 445     I_IHDUSE,CB_EU_FOR,PC_IND_IU3,2012
# 446    I_IHDUSE,CB_EU_FOR,PC_IND_IUHD,2012
# Name: indic_is,ind_type,unit,time\geo, Length: 447, dtype: object

# %%
# 5
df_desc = df_desc.str.split(',', expand=True)
df_desc
# Out:
#              0          1            2     3
# 0     I_IHDDAY  CB_EU_FOR       PC_IND  2012
# 1     I_IHDDAY  CB_EU_FOR   PC_IND_IU3  2012
# 2     I_IHDDAY  CB_EU_FOR  PC_IND_IUHD  2012
# 3     I_IHDDAY  CB_EXT_EU       PC_IND  2012
# 4     I_IHDDAY  CB_EXT_EU   PC_IND_IU3  2012
# ..         ...        ...          ...   ...
# 442  I_IHDLTWK    Y75_MAX   PC_IND_IU3  2012
# 443  I_IHDLTWK    Y75_MAX  PC_IND_IUHD  2012
# 444   I_IHDUSE  CB_EU_FOR       PC_IND  2012
# 445   I_IHDUSE  CB_EU_FOR   PC_IND_IU3  2012
# 446   I_IHDUSE  CB_EU_FOR  PC_IND_IUHD  2012
#
# [447 rows x 4 columns]

# %%
df_desc.rename({0: 'indic_is', 1: 'ind_type', 2: 'unit', 3: 'time'}, axis=1)
# Out:
#       indic_is   ind_type         unit  time
# 0     I_IHDDAY  CB_EU_FOR       PC_IND  2012
# 1     I_IHDDAY  CB_EU_FOR   PC_IND_IU3  2012
# 2     I_IHDDAY  CB_EU_FOR  PC_IND_IUHD  2012
# 3     I_IHDDAY  CB_EXT_EU       PC_IND  2012
# 4     I_IHDDAY  CB_EXT_EU   PC_IND_IU3  2012
# ..         ...        ...          ...   ...
# 442  I_IHDLTWK    Y75_MAX   PC_IND_IU3  2012
# 443  I_IHDLTWK    Y75_MAX  PC_IND_IUHD  2012
# 444   I_IHDUSE  CB_EU_FOR       PC_IND  2012
# 445   I_IHDUSE  CB_EU_FOR   PC_IND_IU3  2012
# 446   I_IHDUSE  CB_EU_FOR  PC_IND_IUHD  2012
#
# [447 rows x 4 columns]

# %%
# 6
df_desc.rename({0: 'indic_is', 1: 'ind_type', 2: 'unit', 3: 'time'}, axis=1, inplace=True)

# %%
# 7
df_desc.join(df)
# Out:
#       indic_is   ind_type         unit  time  \
# 0     I_IHDDAY  CB_EU_FOR       PC_IND  2012
# 1     I_IHDDAY  CB_EU_FOR   PC_IND_IU3  2012
# 2     I_IHDDAY  CB_EU_FOR  PC_IND_IUHD  2012
# 3     I_IHDDAY  CB_EXT_EU       PC_IND  2012
# 4     I_IHDDAY  CB_EXT_EU   PC_IND_IU3  2012
# ..         ...        ...          ...   ...
# 442  I_IHDLTWK    Y75_MAX   PC_IND_IU3  2012
# 443  I_IHDLTWK    Y75_MAX  PC_IND_IUHD  2012
# 444   I_IHDUSE  CB_EU_FOR       PC_IND  2012
# 445   I_IHDUSE  CB_EU_FOR   PC_IND_IU3  2012
# 446   I_IHDUSE  CB_EU_FOR  PC_IND_IUHD  2012
#
#          indic_is,ind_type,unit,time\geo EU28  EU27  EU15   EA   BE   ...  \
# 0         I_IHDDAY,CB_EU_FOR,PC_IND,2012   15    15    16   12   15   ...
# 1     I_IHDDAY,CB_EU_FOR,PC_IND_IU3,2012   21    21    21   17   19   ...
# 2    I_IHDDAY,CB_EU_FOR,PC_IND_IUHD,2012   57    57    57   55   48   ...
# 3         I_IHDDAY,CB_EXT_EU,PC_IND,2012   21    21    22   13   11   ...
# ...

# %%
df_desc = df_desc.join(df)

# %%
# 8
df_desc.drop('indic_is,ind_type,unit,time\geo', axis=1)
# Out:
#       indic_is   ind_type         unit  time EU28  EU27  EU15   EA   BE   \
# 0     I_IHDDAY  CB_EU_FOR       PC_IND  2012   15    15    16   12   15
# 1     I_IHDDAY  CB_EU_FOR   PC_IND_IU3  2012   21    21    21   17   19
# 2     I_IHDDAY  CB_EU_FOR  PC_IND_IUHD  2012   57    57    57   55   48
# 3     I_IHDDAY  CB_EXT_EU       PC_IND  2012   21    21    22   13   11
# 4     I_IHDDAY  CB_EXT_EU   PC_IND_IU3  2012   28    28    29   19   15
# ..         ...        ...          ...   ...   ...   ...   ...  ...  ...
# 442  I_IHDLTWK    Y75_MAX   PC_IND_IU3  2012    :     :     :    :    :
# 443  I_IHDLTWK    Y75_MAX  PC_IND_IUHD  2012    :     :     :    :    :
# 444   I_IHDUSE  CB_EU_FOR       PC_IND  2012   22    22    22   18   26
# 445   I_IHDUSE  CB_EU_FOR   PC_IND_IU3  2012   30    30    30   25   33
# 446   I_IHDUSE  CB_EU_FOR  PC_IND_IUHD  2012   82    82    82   81   82
#
#       BG   ...  SI    SK    FI    SE    UK    IS    NO   ME   MK   TR
# ...

# %%
df_desc.drop('indic_is,ind_type,unit,time\geo', axis=1, inplace=True)

# %%
# 9
pd.read_json('./course-files/course-sources/world-heritage-unesco-list.json')
# Out:
#                        datasetid                                  recordid  \
# 0     world-heritage-unesco-list  ff1f5b718ce2ee87f18dfaf20610f257979f2f4a
# 1     world-heritage-unesco-list  0fd1ad38878a73b01bf59ed430446e098709cea1
# 2     world-heritage-unesco-list  fa66a8d51c28871277f1cdd9c0f2d092a423ff5f
# 3     world-heritage-unesco-list  b16a410e99f603ef138909f6de916de08f0cfdc2
# 4     world-heritage-unesco-list  bb09d483a4ca7411a334314fb13f13301fa51bc0
# ...                          ...                                       ...
# 1047  world-heritage-unesco-list  56eb288886ea2292e967d1f1bffa113716b54a13
# 1048  world-heritage-unesco-list  ba0194f29e91fc29ab548a5d8027732270c545ff
# 1049  world-heritage-unesco-list  9cac2d1355326552b3d7f353477555faca6d121b
# 1050  world-heritage-unesco-list  0d93d20a163f316c5cb8b3380ac1b24efa32b4d2
# 1051  world-heritage-unesco-list  e0008b2c6110a51915e4314b598e736676f0f74d
#
#                                                  fields  \
# ...

# %% [markdown]
# ## L002

# %%
# 2
mcdonalds = pd.read_csv(
    './course-files/course-sources/Mcdonalds.csv',
    usecols=['Category', 'Item', 'Calories', 'TotalFat']
)
mcdonalds
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#      Calories  TotalFat
# 0         300      13.0
# ...

# %%
# 3.1
mcdonalds.to_csv(
    './course-files/course-sources/mc-1.csv',
    index=False
)
pd.read_csv('./course-files/course-sources/mc-1.csv')
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#      Calories  TotalFat
# 0         300      13.0
# ...

# %%
# 3.2
mcdonalds.to_csv(
    './course-files/course-sources/mc-2.csv',
    index=False,
    quoting=csv.QUOTE_NONNUMERIC
)
pd.read_csv('./course-files/course-sources/mc-2.csv')
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#      Calories  TotalFat
# 0         300      13.0
# ...

# %%
# 3.3
mcdonalds.to_csv(
    './course-files/course-sources/mc-2.csv',
    index=False,
    quoting=csv.QUOTE_NONNUMERIC,
    decimal=','
)
pd.read_csv('./course-files/course-sources/mc-2.csv')
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#      Calories TotalFat
# 0         300     13,0
# ...

# %%
# 3.5
mcdonalds.to_csv(
    './course-files/course-sources/mc-5.csv',
    index=False,
    quoting=csv.QUOTE_NONNUMERIC,
    decimal=',',
    columns=['Item', 'TotalFat']
)
pd.read_csv('./course-files/course-sources/mc-5.csv')
# Out:
#                                                   Item TotalFat
# 0                                         Egg McMuffin     13,0
# 1                                    Egg White Delight      8,0
# 2                                     Sausage McMuffin     23,0
# 3                            Sausage McMuffin with Egg     28,0
# 4                     Sausage McMuffin with Egg Whites     23,0
# ..                                                 ...      ...
# 255                 McFlurry with Oreo Cookies (Small)     17,0
# 256                McFlurry with Oreo Cookies (Medium)     23,0
# 257                 McFlurry with Oreo Cookies (Snack)     11,0
# 258  McFlurry with Reese's Peanut Butter Cups (Medium)     32,0
# 259   McFlurry with Reese's Peanut Butter Cups (Snack)     16,0
#
# [260 rows x 2 columns]

# %%
# 4
mcdonalds.to_json(
    './course-files/course-sources/mc-6.json',
#     index=False,
#     quoting=csv.QUOTE_NONNUMERIC,
#     decimal=',',
#     columns=['Item', 'TotalFat']
)
pd.read_json('./course-files/course-sources/mc-6.json')
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#      Calories  TotalFat
# 0         300      13.0
# ...

# %%
# 5
htm = mcdonalds.to_html()
htm
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Category</th>\n      <th>Item</th>\n      <th>Calories</th>\n      <th>TotalFat</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Breakfast</td>\n      <td>Egg McMuffin</td>\n      <td>300</td>\n      <td>13.0</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Breakfast</td>\n      <td>Egg White Delight</td>\n      <td>250</td>\n      <td>8.0</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Breakfast</td>\n      <td>Sausage McMuffin</td>\n      <td>370</td>\n      <td>23.0</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Breakfast</td>\n      <td>Sausage McMuffin with Egg</td>\n      <td>450</td>\n      <td>28.0</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Breakfast</td>\n      <td>Sausage McMuffin with Egg Whites</td>\n      <td>400</td>\n      <td>23.0</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Breakfast<
# ...

# %%
# 6
import io
with open(file='./course-files/course-sources/mc-7.htm', mode='w', encoding='utf-8') as file:
    file.write(htm)

# %% [markdown]
# ## L003

# %%
# 2
mcdonalds = pd.read_csv(
    './course-files/course-sources/Mcdonalds.csv',
    usecols=['Category', 'Item', 'Calories', 'TotalFat']
)
mcdonalds
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#      Calories  TotalFat
# 0         300      13.0
# ...

# %%
# 3, 4, 5
excel_writer = pd.ExcelWriter('./course-files/course-sources/mcdonalds-excel_my_file.xlsx')
mcdonalds.to_excel(excel_writer, sheet_name='Menu', index=False)
excel_writer.save()

# %%
# 6
imported1 = pd.read_excel(
    './course-files/course-sources/mcdonalds-excel_my_file.xlsx'
)
imported1
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#      Calories  TotalFat
# 0         300      13.0
# ...

# %%
# 7
imported1.Calories /= 2
imported1
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#      Calories  TotalFat
# 0       150.0      13.0
# ...

# %%
# 8
excel_writer = pd.ExcelWriter(
    './course-files/course-sources/mcdonalds-excel_my_file.xlsx',
#     engine="openpyxl",  # default engine cannot append !!!
    mode="a"
)
imported1.to_excel(excel_writer, sheet_name='Menu Light', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-821900a804a4> in <module>
#       1 # 8
# ----> 2 excel_writer = pd.ExcelWriter(
#       3     './course-files/course-sources/mcdonalds-excel_my_file.xlsx',
#       4 #     engine="openpyxl",  # default engine cannot append !!!
#       5     mode="a"
#
# D:\programy\Anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, **engine_kwargs)
#     178
#     179         if mode == "a":
# --> 180             raise ValueError("Append mode is not supported with xlsxwriter!")
#     181
#     182         super().__init__(
#
# ValueError: Append mode is not supported with xlsxwriter!

# %%
# 9
imported1.Calories /= 2
imported1
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#      Calories  TotalFat
# 0        75.0      13.0
# ...

# %%
# 10, 11
imported1.to_excel(excel_writer, sheet_name='Menu Extra Light', index=False)
excel_writer.save()

# %%
# 12
final = pd.read_excel('./course-files/course-sources/mcdonalds-excel_my_file.xlsx',
                      sheet_name=[0,1,2])
final
# Out:
# {0:                Category                                               Item  \
#  0             Breakfast                                       Egg McMuffin
#  1             Breakfast                                  Egg White Delight
#  2             Breakfast                                   Sausage McMuffin
#  3             Breakfast                          Sausage McMuffin with Egg
#  4             Breakfast                   Sausage McMuffin with Egg Whites
#  ..                  ...                                                ...
#  255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
#  256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
#  257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
#  258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
#  259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#       Calories  TotalFat
#  0         300      13.0
# ...

# %%
# 13
len(final)
# Out:
# 3

# %%
# 14
final[0].head(2)
# Out:
#     Category               Item  Calories  TotalFat
# 0  Breakfast       Egg McMuffin       300      13.0
# 1  Breakfast  Egg White Delight       250       8.0

# %%
final[1].head(2)
# Out:
#     Category               Item  Calories  TotalFat
# 0  Breakfast       Egg McMuffin     150.0      13.0
# 1  Breakfast  Egg White Delight     125.0       8.0

# %%
final[2].head(2)
# Out:
#     Category               Item  Calories  TotalFat
# 0  Breakfast       Egg McMuffin      75.0      13.0
# 1  Breakfast  Egg White Delight      62.5       8.0
