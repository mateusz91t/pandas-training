# %% [markdown]
# # Labs 07 (Section 9 - Data joins)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from datetime import datetime, timedelta, time

# %matplotlib inline

# %% [markdown]
# ## L001

# %%
categories = pd.read_csv('./course-files/course-sources/northwind-mongo-master/categories1.csv')
products = pd.read_csv('./course-files/course-sources/northwind-mongo-master/products.csv')
suppliers = pd.read_csv('./course-files/course-sources/northwind-mongo-master/suppliers.csv')
customers = pd.read_csv('./course-files/course-sources/northwind-mongo-master/customers.csv')

# %%
categories.head()
# Out:
#    CategoryID    CategoryName              Description
# 0           1       Beverages              Soft drinks
# 1           2      Condiments  Sweet and savory sauces
# 2           3     Confections                 Desserts
# 3           4  Dairy Products                  Cheeses
# 4           5  Grains/Cereals                   Breads

# %%
products.head()
# Out:
#    ProductID                   ProductName  SupplierID  CategoryID  \
# 0          1                          Chai           1           1
# 1          2                         Chang           1           1
# 2          3                 Aniseed Syrup           1           2
# 3          4  Chef Anton's Cajun Seasoning           2           2
# 4          5        Chef Anton's Gumbo Mix           2           2
#
#        QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 0   10 boxes x 20 bags      18.00            39             0            10
# 1   24 - 12 oz bottles      19.00            17            40            25
# 2  12 - 550 ml bottles      10.00            13            70            25
# 3       48 - 6 oz jars      22.00            53             0             0
# 4             36 boxes      21.35             0             0             0
#
#    Discontinued
# 0             0
# 1             0
# 2             0
# 3             0
# 4             1

# %%
suppliers.head()
# Out:
#    SupplierID                         CompanyName                 ContactName  \
# 0           1                      Exotic Liquids            Charlotte Cooper
# 1           2          New Orleans Cajun Delights               Shelley Burke
# 2           3           Grandma Kelly's Homestead               Regina Murphy
# 3           4                       Tokyo Traders                Yoshi Nagase
# 4           5  Cooperativa de Quesos 'Las Cabras'  Antonio del Valle Saavedra
#
#            ContactTitle                    Address         City    Region  \
# 0    Purchasing Manager             49 Gilbert St.       London       NaN
# 1   Order Administrator             P.O. Box 78934  New Orleans        LA
# 2  Sales Representative             707 Oxford Rd.    Ann Arbor        MI
# 3     Marketing Manager  9-8 Sekimai Musashino-shi        Tokyo       NaN
# 4  Export Administrator          Calle del Rosal 4       Oviedo  Asturias
#
# ...

# %%
customers.head()
# Out:
#   CustomerID                         CompanyName         ContactName  \
# 0      ALFKI                 Alfreds Futterkiste        Maria Anders
# 1      ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2      ANTON            Antonio Moreno Taquer?­a      Antonio Moreno
# 3      AROUT                     Around the Horn        Thomas Hardy
# 4      BERGS                 Berglunds snabbk?¶p  Christina Berglund
#
#            ContactTitle                         Address          City Region  \
# 0  Sales Representative                   Obere Str. 57        Berlin    NaN
# 1                 Owner  Avda. de la Constituci??n 2222  M?©xico D.F.    NaN
# 2                 Owner                 Mataderos  2312  M?©xico D.F.    NaN
# 3  Sales Representative                 120 Hanover Sq.        London    NaN
# 4   Order Administrator                Berguvsv?¤gen  8        Lule??    NaN
#
#   PostalCode  Country           Phone             Fax
# ...

# %%
# 3
products[products['ProductName'] == 'Ravioli Angelo']
# Out:
#     ProductID     ProductName  SupplierID  CategoryID   QuantityPerUnit  \
# 56         57  Ravioli Angelo          26           5  24 - 250 g pkgs.
#
#     UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  Discontinued
# 56       19.5            36             0            20             0

# %%
# 5
categories[categories['CategoryID'] == 5]
# Out:
#    CategoryID    CategoryName Description
# 4           5  Grains/Cereals      Breads

# %%
# 7
suppliers[suppliers['SupplierID'] == 26]
# Out:
#     SupplierID           CompanyName       ContactName         ContactTitle  \
# 25          26  Pasta Buttini s.r.l.  Giovanni Giudici  Order Administrator
#
#                   Address     City Region PostalCode Country          Phone  \
# 25  Via dei Gelsomini 153  Salerno    NaN      84100   Italy  (089) 6547665
#
#               Fax HomePage
# 25  (089) 6547667      NaN

# %% [markdown]
# ## L002

# %%
mrbean = pd.read_csv(
    './course-files/course-sources/mrbean_facebook_statuses_join.csv',
    usecols=['status_message_mrbean','status_type','num_likes']
)
mrbean.head()
# Out:
#                                status_message_mrbean status_type  num_likes
# 0  It's time for Mr Bean and Teddy to get ready f...       video      16079
# 1                                                NaN       photo     114008
# 2                                                NaN       photo     218579
# 3  Mr Bean is ready to do some shopping but bewar...       video      20338
# 4                                                NaN       photo     215591

# %%
nasa = pd.read_csv(
    './course-files/course-sources/nasa_facebook_statuses_join.csv',
    usecols=['status_message_nasa','status_type','num_likes']
)
nasa.head()
# Out:
#                                  status_message_nasa status_type  num_likes
# 0  This morning, the #RockOn mission with student...       photo       5142
# 1  Pluto's largest moon, Charon, is home to an un...       photo      19074
# 2  Our Restore-L mission is an endeavor to launch...       photo       7551
# 3  A new dark vortex was discovered in the atmosp...       photo      24359
# 4                                                NaN       video       2731

# %%
len(mrbean), len(nasa)
# Out:
# (56, 763)

# %%
# 5
fb = mrbean.append(nasa, sort=True)
fb.iloc[50:60]
# Out:
#     num_likes                              status_message_mrbean  \
# 50      23946  What score out of 10 would you award Mr Bean f...
# 51     274426                                     Happy Friday!!
# 52      17896  Mr Bean and Teddy learn a valuable lesson abou...
# 53      28857  Mr. Bean is having fun at the Country Fete, no...
# 54      29372  Look at this AMAZING Mr. Bean made out of Lego...
# 55      21741  Watch Mr Bean plan his great escape…\nhttps://...
# 0        5142                                                NaN
# 1       19074                                                NaN
# 2        7551                                                NaN
# 3       24359                                                NaN
#
#                                   status_message_nasa status_type
# 50                                                NaN       video
# 51                                                NaN       photo
# ...

# %%
# 7
fb.loc[0]
# Out:
#    num_likes                              status_message_mrbean  \
# 0      16079  It's time for Mr Bean and Teddy to get ready f...
# 0       5142                                                NaN
#
#                                  status_message_nasa status_type
# 0                                                NaN       video
# 0  This morning, the #RockOn mission with student...       photo

# %%
# 8
fb = mrbean.append(nasa, ignore_index=True, sort=True)
fb.iloc[50:60]
# Out:
#     num_likes                              status_message_mrbean  \
# 50      23946  What score out of 10 would you award Mr Bean f...
# 51     274426                                     Happy Friday!!
# 52      17896  Mr Bean and Teddy learn a valuable lesson abou...
# 53      28857  Mr. Bean is having fun at the Country Fete, no...
# 54      29372  Look at this AMAZING Mr. Bean made out of Lego...
# 55      21741  Watch Mr Bean plan his great escape…\nhttps://...
# 56       5142                                                NaN
# 57      19074                                                NaN
# 58       7551                                                NaN
# 59      24359                                                NaN
#
#                                   status_message_nasa status_type
# 50                                                NaN       video
# 51                                                NaN       photo
# ...

# %%
fb.loc[0]
# Out:
# num_likes                                                            16079
# status_message_mrbean    It's time for Mr Bean and Teddy to get ready f...
# status_message_nasa                                                    NaN
# status_type                                                          video
# Name: 0, dtype: object

# %%
mrbean.rename({'status_message_mrbean': 'status_message'}, axis='columns', inplace=True)
nasa.rename({'status_message_nasa': 'status_message'}, axis='columns', inplace=True)
# 11
fb = mrbean.append(nasa, ignore_index=True, sort=True)
fb.iloc[50:60]
# Out:
#     num_likes                                     status_message status_type
# 50      23946  What score out of 10 would you award Mr Bean f...       video
# 51     274426                                     Happy Friday!!       photo
# 52      17896  Mr Bean and Teddy learn a valuable lesson abou...       video
# 53      28857  Mr. Bean is having fun at the Country Fete, no...       video
# 54      29372  Look at this AMAZING Mr. Bean made out of Lego...        link
# 55      21741  Watch Mr Bean plan his great escape…\nhttps://...       video
# 56       5142  This morning, the #RockOn mission with student...       photo
# 57      19074  Pluto's largest moon, Charon, is home to an un...       photo
# 58       7551  Our Restore-L mission is an endeavor to launch...       photo
# 59      24359  A new dark vortex was discovered in the atmosp...       photo

# %%
# 12
fb = pd.concat(objs=[mrbean, nasa], ignore_index=True, sort=True)
fb.iloc[50:60]
# Out:
#     num_likes                                     status_message status_type
# 50      23946  What score out of 10 would you award Mr Bean f...       video
# 51     274426                                     Happy Friday!!       photo
# 52      17896  Mr Bean and Teddy learn a valuable lesson abou...       video
# 53      28857  Mr. Bean is having fun at the Country Fete, no...       video
# 54      29372  Look at this AMAZING Mr. Bean made out of Lego...        link
# 55      21741  Watch Mr Bean plan his great escape…\nhttps://...       video
# 56       5142  This morning, the #RockOn mission with student...       photo
# 57      19074  Pluto's largest moon, Charon, is home to an un...       photo
# 58       7551  Our Restore-L mission is an endeavor to launch...       photo
# 59      24359  A new dark vortex was discovered in the atmosp...       photo

# %% [markdown]
# ## L003

# %%
customer_names = pd.read_csv(
    './course-files/course-sources/northwind-mongo-master/customers.csv',
    usecols=['CustomerID', 'CompanyName']
)
customer_names.head(2)
# Out:
#   CustomerID                         CompanyName
# 0      ALFKI                 Alfreds Futterkiste
# 1      ANATR  Ana Trujillo Emparedados y helados

# %%
customer_cities = pd.read_csv(
    './course-files/course-sources/northwind-mongo-master/customers.csv',
    usecols=['CustomerID', 'City', 'Country']
)
customer_cities.head(2)
# Out:
#   CustomerID          City  Country
# 0      ALFKI        Berlin  Germany
# 1      ANATR  M?©xico D.F.   Mexico

# %%
len(customer_names), len(customer_cities)
# Out:
# (91, 91)

# %%
customer_names.set_index('CustomerID', inplace=True)
customer_cities.set_index('CustomerID', inplace=True)
customer_cities.head(2)
# Out:
#                     City  Country
# CustomerID
# ALFKI             Berlin  Germany
# ANATR       M?©xico D.F.   Mexico

# %%
customer_names.head(2)
# Out:
#                                    CompanyName
# CustomerID
# ALFKI                      Alfreds Futterkiste
# ANATR       Ana Trujillo Emparedados y helados

# %%
customer_names.join(customer_cities)
# Out:
#                                    CompanyName          City  Country
# CustomerID
# ALFKI                      Alfreds Futterkiste        Berlin  Germany
# ANATR       Ana Trujillo Emparedados y helados  M?©xico D.F.   Mexico
# ANTON                 Antonio Moreno Taquer?­a  M?©xico D.F.   Mexico
# AROUT                          Around the Horn        London       UK
# BERGS                      Berglunds snabbk?¶p        Lule??   Sweden
# ...                                        ...           ...      ...
# WARTH                           Wartian Herkku          Oulu  Finland
# WELLI                   Wellington Importadora       Resende   Brazil
# WHITC                     White Clover Markets       Seattle      USA
# WILMK                              Wilman Kala      Helsinki  Finland
# WOLZA                           Wolski  Zajazd      Warszawa   Poland
#
# [91 rows x 3 columns]

# %%
customer_names.reset_index(inplace=True)
customer_names.head(2)
# Out:
#   CustomerID                         CompanyName
# 0      ALFKI                 Alfreds Futterkiste
# 1      ANATR  Ana Trujillo Emparedados y helados

# %%
# arg `other` must have an index base on will be done the join
# customer_cities.join(customer_names, on='CustomerID')  # ValueError
customer_names.join(customer_cities, on='CustomerID')
# Out:
#    CustomerID                         CompanyName          City  Country
# 0       ALFKI                 Alfreds Futterkiste        Berlin  Germany
# 1       ANATR  Ana Trujillo Emparedados y helados  M?©xico D.F.   Mexico
# 2       ANTON            Antonio Moreno Taquer?­a  M?©xico D.F.   Mexico
# 3       AROUT                     Around the Horn        London       UK
# 4       BERGS                 Berglunds snabbk?¶p        Lule??   Sweden
# ..        ...                                 ...           ...      ...
# 86      WARTH                      Wartian Herkku          Oulu  Finland
# 87      WELLI              Wellington Importadora       Resende   Brazil
# 88      WHITC                White Clover Markets       Seattle      USA
# 89      WILMK                         Wilman Kala      Helsinki  Finland
# 90      WOLZA                      Wolski  Zajazd      Warszawa   Poland
#
# [91 rows x 4 columns]

# %% [markdown]
# ## L004

# %%
f_2015 = pd.read_csv(
    './course-files/course-sources/Fortune_500_2015.csv',
    usecols=['rank', 'company']
)
f_2015.head()
# Out:
#    rank             company
# 0     1             Walmart
# 1     2         Exxon Mobil
# 2     3             Chevron
# 3     4  Berkshire Hathaway
# 4     5               Apple

# %%
f_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rank     500 non-null    int64
#  1   company  500 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 7.9+ KB

# %%
f_2016 = pd.read_csv(
    './course-files/course-sources/Fortune_500_2016.csv',
    usecols=['rank', 'company']
)
f_2016.head()
# Out:
#    rank             company
# 0     1             Walmart
# 1     2         Exxon Mobil
# 2     3               Apple
# 3     4  Berkshire Hathaway
# 4     5            McKesson

# %%
# 4
f_2015.merge(f_2016, on='company', indicator=True)
# Out:
#      rank_x                company  rank_y _merge
# 0         1                Walmart       1   both
# 1         2            Exxon Mobil       2   both
# 2         3                Chevron      14   both
# 3         4     Berkshire Hathaway       4   both
# 4         5                  Apple       3   both
# ..      ...                    ...     ...    ...
# 461     493    Insight Enterprises     474   both
# 462     494  Alliance Data Systems     404   both
# 463     495       LifePoint Health     430   both
# 464     497      Wyndham Worldwide     466   both
# 465     498          Owens Corning     480   both
#
# [466 rows x 4 columns]

# %%
# 4
companies_15_only = f_2015.merge(f_2016, on='company', how='left', indicator=True)
companies_15_only[companies_15_only['_merge'] == 'left_only']
# Out:
#      rank_x                              company  rank_y     _merge
# 83       84                              Safeway     NaN  left_only
# 94       95                              DirecTV     NaN  left_only
# 124     125                                Alcoa     NaN  left_only
# 164     165                                Kraft     NaN  left_only
# 174     175              TRW Automotive Holdings     NaN  left_only
# 214     215                                Chubb     NaN  left_only
# 271     272                           H.J. Heinz     NaN  left_only
# 280     281                 Family Dollar Stores     NaN  left_only
# 327     328                Caesars Entertainment     NaN  left_only
# 349     350                           Murphy Oil     NaN  left_only
# 367     368                Coca-Cola Enterprises     NaN  left_only
# 372     373                     Blackstone Group     NaN  left_only
# 379     380                             Allergan     NaN  left_only
# ...

# %%
# 4
companies_16_only = f_2015.merge(f_2016, on='company', how='right', indicator=True)
companies_16_only[companies_16_only['_merge'] == 'right_only']
# Out:
#      rank_x                       company  rank_y      _merge
# 125     NaN                       Arconic     126  right_only
# 152     NaN                   Kraft Heinz     153  right_only
# 184     NaN        Performance Food Group     185  right_only
# 268     NaN         Hertz Global Holdings     269  right_only
# 306     NaN               PayPal Holdings     307  right_only
# 314     NaN                        Univar     315  right_only
# 322     NaN                       Veritiv     323  right_only
# 352     NaN                 XPO Logistics     353  right_only
# 396     NaN   Coca-Cola European Partners     397  right_only
# 419     NaN                       Baxalta     420  right_only
# 428     NaN          Constellation Brands     429  right_only
# 430     NaN        Zimmer Biomet Holdings     431  right_only
# 436     NaN              WEC Energy Group     437  right_only
# 446     NaN        Quintiles IMS Holdings     447  right_only
# ...

# %%
# 5
companies_2015_2016 = f_2015.merge(f_2016, on='company', indicator=True)
companies_2015_2016
# Out:
#      rank_x                company  rank_y _merge
# 0         1                Walmart       1   both
# 1         2            Exxon Mobil       2   both
# 2         3                Chevron      14   both
# 3         4     Berkshire Hathaway       4   both
# 4         5                  Apple       3   both
# ..      ...                    ...     ...    ...
# 461     493    Insight Enterprises     474   both
# 462     494  Alliance Data Systems     404   both
# 463     495       LifePoint Health     430   both
# 464     497      Wyndham Worldwide     466   both
# 465     498          Owens Corning     480   both
#
# [466 rows x 4 columns]

# %%
# 6
f_2015.merge(f_2016, on='company', suffixes=['_2015', '_2016'], indicator=True)
# Out:
#      rank_2015                company  rank_2016 _merge
# 0            1                Walmart          1   both
# 1            2            Exxon Mobil          2   both
# 2            3                Chevron         14   both
# 3            4     Berkshire Hathaway          4   both
# 4            5                  Apple          3   both
# ..         ...                    ...        ...    ...
# 461        493    Insight Enterprises        474   both
# 462        494  Alliance Data Systems        404   both
# 463        495       LifePoint Health        430   both
# 464        497      Wyndham Worldwide        466   both
# 465        498          Owens Corning        480   both
#
# [466 rows x 4 columns]

# %%
# 7
companies_2015_2016[companies_2015_2016['company'] == 'Microsoft']
# Out:
#     rank_x    company  rank_y _merge
# 30      31  Microsoft      25   both

# %%
# 8
companies_2015_2016 = f_2015.merge(
    f_2016,
    how='outer',
    on='company',
    suffixes=['_2015', '_2016'],
    indicator=True
)
companies_2015_2016
# Out:
#      rank_2015                   company  rank_2016      _merge
# 0          1.0                   Walmart        1.0        both
# 1          2.0               Exxon Mobil        2.0        both
# 2          3.0                   Chevron       14.0        both
# 3          4.0        Berkshire Hathaway        4.0        both
# 4          5.0                     Apple        3.0        both
# ..         ...                       ...        ...         ...
# 529        NaN  Telephone & Data Systems      496.0  right_only
# 530        NaN  First American Financial      497.0  right_only
# 531        NaN                       NVR      498.0  right_only
# 532        NaN      Cincinnati Financial      499.0  right_only
# 533        NaN         Burlington Stores      500.0  right_only
#
# [534 rows x 4 columns]

# %% [markdown]
# ## L005

# %%
suppliers = pd.read_csv(
    './course-files/course-sources/northwind-mongo-master/suppliers _del_1.csv',
    usecols=['SupplierID', 'CompanyName', 'City']
)
suppliers.head()
# Out:
#    SupplierID                         CompanyName         City
# 0           1                      Exotic Liquids       London
# 1           2          New Orleans Cajun Delights  New Orleans
# 2           3           Grandma Kelly's Homestead    Ann Arbor
# 3           4                       Tokyo Traders        Tokyo
# 4           5  Cooperativa de Quesos 'Las Cabras'       Oviedo

# %%
products = pd.read_csv(
    './course-files/course-sources/northwind-mongo-master/products_del_1.csv',
    usecols=['SupplierID', 'ProductID', 'ProductName']
)
products.head()
# Out:
#    ProductID                   ProductName  SupplierID
# 0          1                          Chai           1
# 1          2                         Chang           1
# 2          3                 Aniseed Syrup           1
# 3          4  Chef Anton's Cajun Seasoning           2
# 4          5        Chef Anton's Gumbo Mix           2

# %%
len(products), len(suppliers)
# Out:
# (75, 27)

# %%
# 4, 5
prod_and_sup = products.merge(suppliers, on='SupplierID')
prod_and_sup
# Out:
#     ProductID                   ProductName  SupplierID  \
# 0           1                          Chai           1
# 1           2                         Chang           1
# 2           3                 Aniseed Syrup           1
# 3           4  Chef Anton's Cajun Seasoning           2
# 4           5        Chef Anton's Gumbo Mix           2
# ..        ...                           ...         ...
# 65         56        Gnocchi di nonna Alice          26
# 66         57                Ravioli Angelo          26
# 67         60             Camembert Pierrot          28
# 68         61                Sirop d'érable          29
# 69         62                Tarte au sucre          29
#
#                    CompanyName           City
# 0               Exotic Liquids         London
# 1               Exotic Liquids         London
# 2               Exotic Liquids         London
# 3   New Orleans Cajun Delights    New Orleans
# 4   New Orleans Cajun Delights    New Orleans
# ...

# %%
# 6
prods_supp_outer_merge = products.merge(suppliers, how='outer', on='SupplierID', indicator=True)
prods_supp_outer_merge[
    prods_supp_outer_merge['_merge'] == 'left_only'
]
# Out:
#     ProductID          ProductName  SupplierID CompanyName City     _merge
# 27       22.0  Gustaf's Knäckebröd           9         NaN  NaN  left_only
# 28       23.0             Tunnbröd           9         NaN  NaN  left_only
# 48       36.0          Inlagd Sill          17         NaN  NaN  left_only
# 49       37.0           Gravad lax          17         NaN  NaN  left_only
# 50       73.0           Röd Kaviar          17         NaN  NaN  left_only

# %%
# 7
prods_supp_outer_merge[
    prods_supp_outer_merge['_merge'] == 'right_only'
]
# Out:
#     ProductID ProductName  SupplierID         CompanyName      City  \
# 75        NaN         NaN          27  Escargots Nouveaux  Montceau
#
#         _merge
# 75  right_only

# %% [markdown]
# ## L006

# %%
suppliers = pd.read_csv(
    './course-files/course-sources/northwind-mongo-master/suppliers _del_1.csv',
    usecols=['SupplierID', 'CompanyName', 'City']
)
suppliers.head()
# Out:
#    SupplierID                         CompanyName         City
# 0           1                      Exotic Liquids       London
# 1           2          New Orleans Cajun Delights  New Orleans
# 2           3           Grandma Kelly's Homestead    Ann Arbor
# 3           4                       Tokyo Traders        Tokyo
# 4           5  Cooperativa de Quesos 'Las Cabras'       Oviedo

# %%
products = pd.read_csv(
    './course-files/course-sources/northwind-mongo-master/products_del_1.csv',
    usecols=['SupplierID', 'ProductID', 'ProductName']
)
products.head()
# Out:
#    ProductID                   ProductName  SupplierID
# 0          1                          Chai           1
# 1          2                         Chang           1
# 2          3                 Aniseed Syrup           1
# 3          4  Chef Anton's Cajun Seasoning           2
# 4          5        Chef Anton's Gumbo Mix           2

# %%
sup_prod = suppliers.merge(right=products, how='outer', on='SupplierID', indicator=True)
sup_prod
# Out:
#     SupplierID                 CompanyName         City  ProductID  \
# 0            1              Exotic Liquids       London        1.0
# 1            1              Exotic Liquids       London        2.0
# 2            1              Exotic Liquids       London        3.0
# 3            2  New Orleans Cajun Delights  New Orleans        4.0
# 4            2  New Orleans Cajun Delights  New Orleans        5.0
# ..         ...                         ...          ...        ...
# 71           9                         NaN          NaN       22.0
# 72           9                         NaN          NaN       23.0
# 73          17                         NaN          NaN       36.0
# 74          17                         NaN          NaN       37.0
# 75          17                         NaN          NaN       73.0
#
#                      ProductName      _merge
# 0                           Chai        both
# 1                          Chang        both
# ...

# %%
sup_prod[sup_prod['_merge'] == 'left_only']
# Out:
#     SupplierID         CompanyName      City  ProductID ProductName     _merge
# 67          27  Escargots Nouveaux  Montceau        NaN         NaN  left_only

# %%
prod_sup = products.merge(right=suppliers, how='outer', on='SupplierID', indicator=True)
prod_sup
# Out:
#     ProductID                   ProductName  SupplierID  \
# 0         1.0                          Chai           1
# 1         2.0                         Chang           1
# 2         3.0                 Aniseed Syrup           1
# 3         4.0  Chef Anton's Cajun Seasoning           2
# 4         5.0        Chef Anton's Gumbo Mix           2
# ..        ...                           ...         ...
# 71       57.0                Ravioli Angelo          26
# 72       60.0             Camembert Pierrot          28
# 73       61.0                Sirop d'érable          29
# 74       62.0                Tarte au sucre          29
# 75        NaN                           NaN          27
#
#                    CompanyName           City      _merge
# 0               Exotic Liquids         London        both
# 1               Exotic Liquids         London        both
# 2               Exotic Liquids         London        both
# ...

# %%
prod_sup[prod_sup['_merge'] == 'right_only']
# Out:
#     ProductID ProductName  SupplierID         CompanyName      City  \
# 75        NaN         NaN          27  Escargots Nouveaux  Montceau
#
#         _merge
# 75  right_only

# %% [markdown]
# ## L007

# %%
suppliers = pd.read_csv(
    './course-files/course-sources/northwind-mongo-master/suppliers.csv',
    usecols=['SupplierID', 'CompanyName', 'City']
)
suppliers.head()
# Out:
#    SupplierID                         CompanyName         City
# 0           1                      Exotic Liquids       London
# 1           2          New Orleans Cajun Delights  New Orleans
# 2           3           Grandma Kelly's Homestead    Ann Arbor
# 3           4                       Tokyo Traders        Tokyo
# 4           5  Cooperativa de Quesos 'Las Cabras'       Oviedo

# %%
products = pd.read_csv(
    './course-files/course-sources/northwind-mongo-master/products.csv',
    usecols=['SupplierID', 'ProductID', 'ProductName']
)
products.head()
# Out:
#    ProductID                   ProductName  SupplierID
# 0          1                          Chai           1
# 1          2                         Chang           1
# 2          3                 Aniseed Syrup           1
# 3          4  Chef Anton's Cajun Seasoning           2
# 4          5        Chef Anton's Gumbo Mix           2

# %%
# 5
products.merge(right=suppliers)
# Out:
#     ProductID                   ProductName  SupplierID  \
# 0           1                          Chai           1
# 1           2                         Chang           1
# 2           3                 Aniseed Syrup           1
# 3           4  Chef Anton's Cajun Seasoning           2
# 4           5        Chef Anton's Gumbo Mix           2
# ..        ...                           ...         ...
# 72         58        Escargots de Bourgogne          27
# 73         59          Raclette Courdavault          28
# 74         60             Camembert Pierrot          28
# 75         61                Sirop d'érable          29
# 76         62                Tarte au sucre          29
#
#                    CompanyName           City
# 0               Exotic Liquids         London
# 1               Exotic Liquids         London
# 2               Exotic Liquids         London
# 3   New Orleans Cajun Delights    New Orleans
# 4   New Orleans Cajun Delights    New Orleans
# ...

# %%
# 5'
products.merge(right=suppliers, on='SupplierID')
# Out:
#     ProductID                   ProductName  SupplierID  \
# 0           1                          Chai           1
# 1           2                         Chang           1
# 2           3                 Aniseed Syrup           1
# 3           4  Chef Anton's Cajun Seasoning           2
# 4           5        Chef Anton's Gumbo Mix           2
# ..        ...                           ...         ...
# 72         58        Escargots de Bourgogne          27
# 73         59          Raclette Courdavault          28
# 74         60             Camembert Pierrot          28
# 75         61                Sirop d'érable          29
# 76         62                Tarte au sucre          29
#
#                    CompanyName           City
# 0               Exotic Liquids         London
# 1               Exotic Liquids         London
# 2               Exotic Liquids         London
# 3   New Orleans Cajun Delights    New Orleans
# 4   New Orleans Cajun Delights    New Orleans
# ...

# %%
suppliers.set_index('SupplierID', inplace=True)
suppliers.head(2)
# Out:
#                            CompanyName         City
# SupplierID
# 1                       Exotic Liquids       London
# 2           New Orleans Cajun Delights  New Orleans

# %%
# 6
suppliers.merge(right=products, left_on='SupplierID', right_index=True).head(2)
# Out:
#                            CompanyName         City  ProductID    ProductName  \
# SupplierID
# 1                       Exotic Liquids       London          2          Chang
# 2           New Orleans Cajun Delights  New Orleans          3  Aniseed Syrup
#
#             SupplierID
# SupplierID
# 1                    1
# 2                    1

# %%
# 7
products.set_index('SupplierID', inplace=True)
suppliers.merge(right=products, left_index=True, right_index=True).head(2)
# Out:
#                CompanyName    City  ProductID ProductName
# SupplierID
# 1           Exotic Liquids  London          1        Chai
# 1           Exotic Liquids  London          2       Chang

# %%
# 8
suppliers.reset_index(inplace=True)
suppliers.merge(right=products, left_on='SupplierID', right_index=True).head(2)
# Out:
#    SupplierID     CompanyName    City  ProductID ProductName
# 0           1  Exotic Liquids  London          1        Chai
# 0           1  Exotic Liquids  London          2       Chang

# %%
# 9.1
products.reset_index(inplace=True)
products.rename({'SupplierID': 'supplier_id'}, inplace=True, axis='columns')
products.head(2)
# Out:
#    supplier_id  ProductID ProductName
# 0            1          1        Chai
# 1            1          2       Chang

# %%
# 9.2
suppliers.merge(right=products, left_on='SupplierID', right_on='supplier_id')
# Out:
#     SupplierID                 CompanyName           City  supplier_id  \
# 0            1              Exotic Liquids         London            1
# 1            1              Exotic Liquids         London            1
# 2            1              Exotic Liquids         London            1
# 3            2  New Orleans Cajun Delights    New Orleans            2
# 4            2  New Orleans Cajun Delights    New Orleans            2
# ..         ...                         ...            ...          ...
# 72          27          Escargots Nouveaux       Montceau           27
# 73          28                Gai pâturage         Annecy           28
# 74          28                Gai pâturage         Annecy           28
# 75          29            Forêts d'érables  Ste-Hyacinthe           29
# 76          29            Forêts d'érables  Ste-Hyacinthe           29
#
#     ProductID                   ProductName
# 0           1                          Chai
# ...

# %% [markdown]
# ## L008

# %%
# 2, 3, 4
suppliers = pd.read_csv(
    './course-files/course-sources/northwind-mongo-master/suppliers.csv',
    usecols=['SupplierID', 'CompanyName', 'City']
)
products = pd.read_csv(
    './course-files/course-sources/northwind-mongo-master/products.csv',
    usecols=['ProductID', 'ProductName', 'CategoryID', 'SupplierID']
)
categories = pd.read_csv(
    './course-files/course-sources/northwind-mongo-master/categories1.csv',
    usecols=['CategoryID', 'CategoryName'],
    index_col='CategoryID'
)

# %%
suppliers.head(2)
# Out:
#    SupplierID                 CompanyName         City
# 0           1              Exotic Liquids       London
# 1           2  New Orleans Cajun Delights  New Orleans

# %%
products.head(2)
# Out:
#    ProductID ProductName  SupplierID  CategoryID
# 0          1        Chai           1           1
# 1          2       Chang           1           1

# %%
categories.head(2)
# Out:
#            CategoryName
# CategoryID
# 1             Beverages
# 2            Condiments

# %%
# 5
prod_cat = products.merge(right=categories, left_on='CategoryID', right_index=True)
prod_cat_sup = prod_cat.merge(right=suppliers, left_on='SupplierID', right_on='SupplierID')
prod_cat_sup.head(2)
# Out:
#    ProductID ProductName  SupplierID  CategoryID CategoryName     CompanyName  \
# 0          1        Chai           1           1    Beverages  Exotic Liquids
# 1          2       Chang           1           1    Beverages  Exotic Liquids
#
#      City
# 0  London
# 1  London

# %%
products.merge(categories, left_on='CategoryID', right_index=True
              ).merge(suppliers, left_on='SupplierID', right_on='SupplierID').head(2)
# Out:
#    ProductID ProductName  SupplierID  CategoryID CategoryName     CompanyName  \
# 0          1        Chai           1           1    Beverages  Exotic Liquids
# 1          2       Chang           1           1    Beverages  Exotic Liquids
#
#      City
# 0  London
# 1  London
